# %%
# !pip install matplotlib
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'matplotlib'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 397, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requirement %s: %s (%s)'
# Arguments: ('already satisfied', <InstallRequirement object: matplotlib in c:\users\\u043d\u0443\u0440\u0430\u043b\u0438\appdata\local\programs\python\python312\lib\site-packages editable=False>, <Version('3.10.8')>)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'contourpy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requirement %s: %s (%s)'
# Arguments: ('already satisfied', <InstallRequirement object: contourpy>=1.0.1 in c:\users\\u043d\u0443\u0440\u0430\u043b\u0438\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) editable=False>, <Version('1.3.3')>)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'cycler'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requirement %s: %s (%s)'
# Arguments: ('already satisfied', <InstallRequirement object: cycler>=0.10 in c:\users\\u043d\u0443\u0440\u0430\u043b\u0438\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) editable=False>, <Version('0.12.1')>)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'fonttools'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requirement %s: %s (%s)'
# Arguments: ('already satisfied', <InstallRequirement object: fonttools>=4.22.0 in c:\users\\u043d\u0443\u0440\u0430\u043b\u0438\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) editable=False>, <Version('4.61.1')>)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kiwisolver'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requirement %s: %s (%s)'
# Arguments: ('already satisfied', <InstallRequirement object: kiwisolver>=1.3.1 in c:\users\\u043d\u0443\u0440\u0430\u043b\u0438\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) editable=False>, <Version('1.4.9')>)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'numpy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
# ...
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requirement %s: %s (%s)'
# Arguments: ('already satisfied', <InstallRequirement object: python-dateutil>=2.7 in c:\users\\u043d\u0443\u0440\u0430\u043b\u0438\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) editable=False>, <Version('2.9.0.post0')>)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'six'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 1672, in print
#     with self:
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 54-59: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 234, in _main
#     return run(options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\base_command.py", line 180, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 230, in _get_updated_criteria
#     self._add_to_criteria(criteria, requirement, parent=candidate)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 148, in _add_to_criteria
#     matches = self._p.find_matches(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\provider.py", line 231, in find_matches
#     return self._factory.find_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 424, in find_candidates
#     return self._iter_found_candidates(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 320, in _iter_found_candidates
#     _get_installed_candidate(),
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 268, in _get_installed_candidate
#     candidate = self._make_candidate_from_dist(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 160, in _make_candidate_from_dist
#     base = AlreadyInstalledCandidate(dist, template, factory=self)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 351, in __init__
#     factory.preparer.prepare_installed_requirement(self._ireq, skip_reason)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\operations\prepare.py", line 732, in prepare_installed_requirement
#     logger.info(
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1539, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1684, in _log
#     self.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1700, in handle
#     self.callHandlers(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1762, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\logging\__init__.py", line 1028, in handle
#     self.emit(record)
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Requirement %s: %s (%s)'
# Arguments: ('already satisfied', <InstallRequirement object: six>=1.5 in c:\users\\u043d\u0443\u0440\u0430\u043b\u0438\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) editable=False>, <Version('1.17.0')>)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Name": ["Alice", "Bob", "Charlie", "Diana", "Evan"],
    "Age": [19, 21, 22, 20, 23],
    "Score": [85, 78, 92, 88, 75]
}

df = pd.DataFrame(data)

# %%
plt.plot(df["Name"], df["Score"])
plt.xlabel("Students")
plt.ylabel("Scores")
plt.title("Student Scores Line Plot")
plt.show()

# %%
plt.bar(df["Name"], df["Score"])
plt.xlabel("Students")
plt.ylabel("Scores")
plt.title("Student Scores Bar Chart")
plt.show()
