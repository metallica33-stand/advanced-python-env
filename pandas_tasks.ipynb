# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 2.7 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.9 MB 7.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 15.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 13.1 MB/s  0:00:01
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\\u041d\u0443\u0440\u0430\u043b\u0438\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 164, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'numpy'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
import pandas as pd

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Diana", "Evan"],
    "Age": [19, 21, 22, 20, 23],
    "Score": [85, 78, 92, 88, 75]
}

df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 1      Bob   21     78
# 2  Charlie   22     92
# 3    Diana   20     88
# 4     Evan   23     75

# %%
df.head(3)

df.describe()

df["Score"].mean()
# Out:
# np.float64(83.6)

# %%
df[df["Age"] > 20]

df[df["Score"] > 80]
# Out:
#       Name  Age  Score
# 0    Alice   19     85
# 2  Charlie   22     92
# 3    Diana   20     88
